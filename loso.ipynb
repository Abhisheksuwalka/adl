# %%
# Core libraries
import os
import joblib

# Numerical and scientific computation
import numpy as np
import pandas as pd

# Signal processing
from scipy.signal import welch
from scipy.fft import fft
from scipy.stats import entropy, skew, kurtosis

# Machine learning
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# Visualization
import matplotlib.pyplot as plt

# Wavelet transform
import pywt

# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, precision_score, recall_score

from sklearn.preprocessing import LabelEncoder

# %%
# Read the DataFrame from the CSV file
import pandas as pd

feature_df = pd.read_csv('./final_time_domain_fft_wavelet_stastical_features_1000_250_40subs.csv')

# Display the DataFrame
# print(feature_df.head())
# Out:
#    muscle_1_mean  muscle_1_median  muscle_1_rms  muscle_1_mav  muscle_1_wl  \
# 0       0.000099         0.000822      0.030228      0.021761     8.613201
# 1      -0.000241         0.000995      0.025578      0.019688     7.820304
# 2       0.000155         0.000422      0.028064      0.022046     8.402600
# 3      -0.000076         0.000957      0.025809      0.019704     7.675642
# 4      -0.000843         0.000425      0.028020      0.020596     7.988726
#
#    muscle_1_zcr  muscle_1_wamp  muscle_1_aac  muscle_1_logd  muscle_1_ssi  \
# 0           114       0.237519      0.008622       0.021322           211
# 1           116       0.206147      0.007828       0.019371           222
# 2           124       0.167535      0.008411       0.021664           204
# 3           120       0.180043      0.007683       0.019381           211
# 4           118       0.249505      0.007997       0.020218           218
#
#    ...  muscle_4_wavelet_level_5_rms  muscle_4_wavelet_level_5_energy  \
# 0  ...                      0.001222                         0.000749
# 1  ...                      0.001073                         0.000578
# 2  ...                      0.001109                         0.000618
# 3  ...                      0.000856                         0.000368
# 4  ...                      0.000893                         0.000400
#
#    muscle_4_wavelet_level_5_skewness  muscle_4_wavelet_level_5_kurtosis  \
# 0                          -0.853446                           7.446621
# 1                          -0.506459                           5.004082
# 2                          -0.708341                           6.361614
# 3                          -0.752806                           5.436700
# 4                          -0.378905                           5.749440
#
#    muscle_4_wavelet_level_5_abs_sum  muscle_4_wavelet_level_5_waveform_length  \
# 0                          0.417394                                  0.581182
# 1                          0.364582                                  0.492136
# 2                          0.363733                                  0.512816
# 3                          0.279479                                  0.405016
# 4                          0.288698                                  0.424437
#
#    muscle_4_wavelet_level_5_zcr  activity_id  cycle_id  subject_id
# 0                           235            1         1           1
# 1                           232            1         1           1
# 2                           242            1         1           1
# 3                           246            1         1           1
# 4                           247            1         1           1
#
# [5 rows x 443 columns]

# %% [markdown]
# ----

# %% [markdown]
# -----

# %% [markdown]
# # Leave One Subject Out

# %%
feature_df
# Out:
#        muscle_1_mean  muscle_1_median  muscle_1_rms  muscle_1_mav  \
# 0           0.000099         0.000822      0.030228      0.021761
# 1          -0.000241         0.000995      0.025578      0.019688
# 2           0.000155         0.000422      0.028064      0.022046
# 3          -0.000076         0.000957      0.025809      0.019704
# 4          -0.000843         0.000425      0.028020      0.020596
# ...              ...              ...           ...           ...
# 31795      -0.000151        -0.001637      0.037032      0.028464
# 31796       0.000808         0.000345      0.037353      0.028798
# 31797       0.000133        -0.001041      0.033897      0.024877
# 31798       0.000316         0.000193      0.038018      0.028840
# 31799      -0.000035         0.000649      0.041183      0.029590
#
#        muscle_1_wl  muscle_1_zcr  muscle_1_wamp  muscle_1_aac  muscle_1_logd  \
# 0         8.613201           114       0.237519      0.008622       0.021322
# 1         7.820304           116       0.206147      0.007828       0.019371
# 2         8.402600           124       0.167535      0.008411       0.021664
# 3         7.675642           120       0.180043      0.007683       0.019381
# 4         7.988726           118       0.249505      0.007997       0.020218
# ...            ...           ...            ...           ...            ...
# 31795    14.613098           154       0.247905      0.014628       0.027807
# 31796    14.194247           167       0.238372      0.014208       0.028128
# 31797    12.176928           148       0.268254      0.012189       0.024326
# 31798    13.550572           148       0.288329      0.013564       0.028149
# 31799    13.567503           146       0.340976      0.013581       0.028786
#
#        muscle_1_ssi  ...  muscle_4_wavelet_level_5_rms  \
# 0               211  ...                      0.001222
# 1               222  ...                      0.001073
# 2               204  ...                      0.001109
# 3               211  ...                      0.000856
# 4               218  ...                      0.000893
# ...             ...  ...                           ...
# 31795           250  ...                      0.000493
# 31796           251  ...                      0.000436
# 31797           246  ...                      0.000504
# 31798           231  ...                      0.000489
# 31799           224  ...                      0.000443
#
#        muscle_4_wavelet_level_5_energy  muscle_4_wavelet_level_5_skewness  \
# 0                             0.000749                          -0.853446
# 1                             0.000578                          -0.506459
# 2                             0.000618                          -0.708341
# 3                             0.000368                          -0.752806
# 4                             0.000400                          -0.378905
# ...                                ...                                ...
# 31795                         0.000122                          -0.280028
# 31796                         0.000095                          -0.226462
# 31797                         0.000128                          -0.166632
# 31798                         0.000120                          -0.054281
# 31799                         0.000098                           0.033604
#
#        muscle_4_wavelet_level_5_kurtosis  muscle_4_wavelet_level_5_abs_sum  \
# 0                               7.446621                          0.417394
# 1                               5.004082                          0.364582
# 2                               6.361614                          0.363733
# 3                               5.436700                          0.279479
# 4                               5.749440                          0.288698
# ...                                  ...                               ...
# 31795                           1.645606                          0.180078
# 31796                           0.800275                          0.168110
# 31797                           0.511613                          0.196714
# 31798                           1.446314                          0.184117
# 31799                           1.556508                          0.169517
#
#        muscle_4_wavelet_level_5_waveform_length  muscle_4_wavelet_level_5_zcr  \
# 0                                      0.581182                           235
# 1                                      0.492136                           232
# 2                                      0.512816                           242
# 3                                      0.405016                           246
# 4                                      0.424437                           247
# ...                                         ...                           ...
# 31795                                  0.266012                           274
# 31796                                  0.249063                           265
# 31797                                  0.283718                           266
# 31798                                  0.272110                           260
# 31799                                  0.246385                           262
#
#        activity_id  cycle_id  subject_id
# 0                1         1           1
# 1                1         1           1
# 2                1         1           1
# 3                1         1           1
# 4                1         1           1
# ...            ...       ...         ...
# 31795           10         5          40
# 31796           10         5          40
# 31797           10         5          40
# 31798           10         5          40
# 31799           10         5          40
#
# [31800 rows x 443 columns]

# %%
# Scaling the Data (StandardScaler or MinMaxScaler based on classifier)
scaler = StandardScaler()  # Use MinMaxScaler() for tree-based models
scaled_features = scaler.fit_transform(feature_df.drop(columns=["activity_id", "cycle_id", "subject_id"]))
scaled_feature_df = pd.DataFrame(scaled_features, columns=feature_df.columns[:-3])
scaled_feature_df["activity_id"] = feature_df["activity_id"]
scaled_feature_df["cycle_id"] = feature_df["cycle_id"]
scaled_feature_df["subject_id"] = feature_df["subject_id"]

# %%
results = []

subjects = 40
for subject in range(1, subjects + 1):
    print(f"- - - - - - - - - - subject id : {subject} - - - - - - - - - -")
    train_data = scaled_feature_df[scaled_feature_df['subject_id'] != subject]
    test_data = scaled_feature_df[scaled_feature_df['subject_id'] == subject]
    X_train = train_data.drop(columns=['activity_id', 'cycle_id', 'subject_id'])
    y_train = train_data['activity_id']
    X_test = test_data.drop(columns=['activity_id', 'cycle_id', 'subject_id'])
    y_test = test_data['activity_id']

    # Encode labels
    label_encoder = LabelEncoder()
    y_train = label_encoder.fit_transform(y_train)
    y_test = label_encoder.transform(y_test)

    # Hyperparameter grid
    param_grid = {
        'bootstrap': [True],
        'max_depth': [20],
        'min_samples_leaf': [1],
        'min_samples_split': [2],
        'n_estimators': [200],
        'class_weight': ['balanced']
    }

    # Random Forest with GridSearchCV
    model = RandomForestClassifier(random_state=42)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)

    # Predictions and metrics
    y_pred = grid_search.best_estimator_.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    # Append results
    results.append({
        'subject_id': subject,
        'best_params': grid_search.best_params_,
        'accuracy': accuracy,
        'f1_score': f1,
        'precision': precision,
        'recall': recall
    })

    # Save confusion matrix to the "./loso" folder
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix for Subject {subject}')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    
    # Save plot as an image
    plt.savefig(f'./loso/confusion_matrix_subject_{subject}.png')
    plt.close()  # Close the plot to free up memory
# Out:
# - - - - - - - - - - subject id : 1 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 3.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 3.0min
# - - - - - - - - - - subject id : 2 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 3.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 3.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.9min
# /Users/abhisheksuwalka/Anaconda/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# - - - - - - - - - - subject id : 3 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 3.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# - - - - - - - - - - subject id : 4 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 5 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# - - - - - - - - - - subject id : 6 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.7min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# - - - - - - - - - - subject id : 7 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# - - - - - - - - - - subject id : 8 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# - - - - - - - - - - subject id : 9 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 10 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.9min
# - - - - - - - - - - subject id : 11 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 12 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.9min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.9min
# - - - - - - - - - - subject id : 13 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 14 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.9min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 2.7min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 2.7min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 2.7min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=31.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=31.8min
# - - - - - - - - - - subject id : 15 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=31.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 8.3min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 8.3min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 8.3min
# - - - - - - - - - - subject id : 16 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=47.4min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=47.4min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=47.4min
# - - - - - - - - - - subject id : 17 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 18 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# - - - - - - - - - - subject id : 19 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 20 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.9min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.9min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.9min
# - - - - - - - - - - subject id : 21 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 22 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 23 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 2.6min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 2.6min
# - - - - - - - - - - subject id : 24 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# - - - - - - - - - - subject id : 25 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.8min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 2.6min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# - - - - - - - - - - subject id : 26 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 27 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 28 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 29 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 30 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# - - - - - - - - - - subject id : 31 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# /Users/abhisheksuwalka/Anaconda/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# - - - - - - - - - - subject id : 32 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# - - - - - - - - - - subject id : 33 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 34 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# - - - - - - - - - - subject id : 35 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 36 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 37 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# - - - - - - - - - - subject id : 38 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# - - - - - - - - - - subject id : 39 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# - - - - - - - - - - subject id : 40 - - - - - - - - - -
# Fitting 3 folds for each of 1 candidates, totalling 3 fits

# %%
# Create DataFrame from results
results_df = pd.DataFrame(results)

# Save results to a CSV file
results_df.to_csv('./loso_classification_results.csv', index=False)

# Display the results DataFrame
print(results_df)
# Out:
#     subject_id                                        best_params  accuracy  \
# 0            1  {'bootstrap': True, 'class_weight': 'balanced'...  0.650314
# 1            2  {'bootstrap': True, 'class_weight': 'balanced'...  0.647799
# 2            3  {'bootstrap': True, 'class_weight': 'balanced'...  0.528302
# 3            4  {'bootstrap': True, 'class_weight': 'balanced'...  0.525786
# 4            5  {'bootstrap': True, 'class_weight': 'balanced'...  0.694340
# 5            6  {'bootstrap': True, 'class_weight': 'balanced'...  0.641509
# 6            7  {'bootstrap': True, 'class_weight': 'balanced'...  0.739623
# 7            8  {'bootstrap': True, 'class_weight': 'balanced'...  0.543396
# 8            9  {'bootstrap': True, 'class_weight': 'balanced'...  0.744654
# 9           10  {'bootstrap': True, 'class_weight': 'balanced'...  0.430189
# 10          11  {'bootstrap': True, 'class_weight': 'balanced'...  0.612579
# 11          12  {'bootstrap': True, 'class_weight': 'balanced'...  0.559748
# 12          13  {'bootstrap': True, 'class_weight': 'balanced'...  0.550943
# 13          14  {'bootstrap': True, 'class_weight': 'balanced'...  0.646541
# 14          15  {'bootstrap': True, 'class_weight': 'balanced'...  0.623899
# 15          16  {'bootstrap': True, 'class_weight': 'balanced'...  0.587421
# 16          17  {'bootstrap': True, 'class_weight': 'balanced'...  0.405031
# 17          18  {'bootstrap': True, 'class_weight': 'balanced'...  0.413836
# 18          19  {'bootstrap': True, 'class_weight': 'balanced'...  0.665409
# 19          20  {'bootstrap': True, 'class_weight': 'balanced'...  0.728302
# 20          21  {'bootstrap': True, 'class_weight': 'balanced'...  0.442767
# 21          22  {'bootstrap': True, 'class_weight': 'balanced'...  0.625157
# 22          23  {'bootstrap': True, 'class_weight': 'balanced'...  0.524528
# 23          24  {'bootstrap': True, 'class_weight': 'balanced'...  0.563522
# 24          25  {'bootstrap': True, 'class_weight': 'balanced'...  0.501887
# 25          26  {'bootstrap': True, 'class_weight': 'balanced'...  0.622642
# 26          27  {'bootstrap': True, 'class_weight': 'balanced'...  0.683019
# 27          28  {'bootstrap': True, 'class_weight': 'balanced'...  0.660377
# 28          29  {'bootstrap': True, 'class_weight': 'balanced'...  0.680503
# 29          30  {'bootstrap': True, 'class_weight': 'balanced'...  0.515723
# 30          31  {'bootstrap': True, 'class_weight': 'balanced'...  0.601258
# 31          32  {'bootstrap': True, 'class_weight': 'balanced'...  0.587421
# 32          33  {'bootstrap': True, 'class_weight': 'balanced'...  0.464151
# 33          34  {'bootstrap': True, 'class_weight': 'balanced'...  0.600000
# 34          35  {'bootstrap': True, 'class_weight': 'balanced'...  0.567296
# 35          36  {'bootstrap': True, 'class_weight': 'balanced'...  0.621384
# 36          37  {'bootstrap': True, 'class_weight': 'balanced'...  0.357233
# 37          38  {'bootstrap': True, 'class_weight': 'balanced'...  0.534591
# 38          39  {'bootstrap': True, 'class_weight': 'balanced'...  0.564780
# 39          40  {'bootstrap': True, 'class_weight': 'balanced'...  0.722013
#
#     f1_score  precision    recall
# 0   0.656498   0.727264  0.650314
# 1   0.615790   0.613102  0.647799
# 2   0.510204   0.635810  0.528302
# 3   0.450906   0.790827  0.525786
# 4   0.680382   0.684498  0.694340
# 5   0.626813   0.661290  0.641509
# 6   0.726514   0.780794  0.739623
# 7   0.543671   0.635339  0.543396
# 8   0.741515   0.769122  0.744654
# 9   0.417772   0.535917  0.430189
# 10  0.606166   0.625299  0.612579
# 11  0.514547   0.516384  0.559748
# 12  0.503705   0.616808  0.550943
# 13  0.652031   0.732715  0.646541
# 14  0.610907   0.688758  0.623899
# 15  0.536926   0.511748  0.587421
# 16  0.367719   0.568740  0.405031
# 17  0.380896   0.481845  0.413836
# 18  0.661949   0.687010  0.665409
# 19  0.737624   0.793253  0.728302
# 20  0.435278   0.515274  0.442767
# 21  0.587599   0.718668  0.625157
# 22  0.501383   0.570219  0.524528
# 23  0.526459   0.603948  0.563522
# 24  0.483702   0.657039  0.501887
# 25  0.613810   0.648174  0.622642
# 26  0.677957   0.716204  0.683019
# 27  0.645381   0.730883  0.660377
# 28  0.670154   0.715503  0.680503
# 29  0.474670   0.491628  0.515723
# 30  0.589640   0.644652  0.601258
# 31  0.557319   0.675546  0.587421
# 32  0.425709   0.537310  0.464151
# 33  0.606723   0.653600  0.600000
# 34  0.568894   0.772215  0.567296
# 35  0.581054   0.593894  0.621384
# 36  0.305145   0.351628  0.357233
# 37  0.517313   0.657272  0.534591
# 38  0.552703   0.643918  0.564780
# 39  0.703926   0.731367  0.722013
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.2min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min

# %%
results_df.drop(columns=['best_params', 'subject_id']).mean()
# Out:
# accuracy     0.584497
# f1_score     0.564184
# precision    0.642137
# recall       0.584497
# dtype: float64
